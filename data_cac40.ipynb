# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
list_cac40 = ['AI.PA', 'AIR.PA', 'ALO.PA', 'MT.AS', 'CS.PA', 'BNP.PA', 'EN.PA', 'CAP.PA', 'CA.PA', 'ACA.PA', 
              'BN.PA', 'DSY.PA', 'ENGI.PA', 'EL.PA', 'ERF.PA', 'RMS.PA', 'KER.PA', 'OR.PA', 'LR.PA', 'MC.PA', 
              'ML.PA', 'ORA.PA', 'RI.PA', 'PUB.PA', 'RNO.PA', 'SAF.PA', 'SGO.PA', 'SAN.PA', 'SU.PA', 'GLE.PA', 
              'STLA.PA', 'STM.PA', 'TEP.PA', 'HO.PA', 'TTE.PA', 'URW.AS', 'VIE.PA', 'DG.PA', 'VIV.PA', 'WLN.PA']

# %%
yf.Ticker('AI.PA').info
# Out:
# {'zip': '75321',
#  'sector': 'Basic Materials',
#  'fullTimeEmployees': 66400,
#  'longBusinessSummary': "L'Air Liquide S.A. provides gases, technologies, and services for the industrial and health sectors in Europe, the Americas, the Asia Pacific, the Middle East, and Africa. The company's Gas & Services segment offers oxygen, nitrogen, argon, hydrogen, and carbon monoxide to the metals, chemicals, refining, and energy sectors; and gases, application equipment, and associated services to the materials and energy, automotive and manufacturing, food and pharmaceuticals, technology and research, and craftsmen and retail sectors. It also supplies medical gases, hygiene products, equipment, and services to hospitals, as well as to patients in their homes; and produces and distributes healthcare specialty ingredients for the cosmetics, pharmaceutical, and vaccine markets. In addition, this segment supplies gases, materials, and services for use in the production of semi-conductors, as well as flat screens and photovoltaic panels. Its Engineering & Construction segment designs, develops, and builds industrial gas production plants for third parties; and designs and manufactures plants in the traditional, renewable, and alternative energy sectors. The company's Global Markets & Technologies segment delivers technological solutions, such as molecules, equipment, and services to support the markets of energy transition, primarily in transport, energy, and waste valorization, as well as related to deep tech in the space exploration, aerospace, and big science. This segment also invests in biomethane production units, as well as develops stations for distributing natural bio-gas for vehicles and hydrogen to support clean mobility; operates biomethane production units for use in the maritime industry; and supplies gases for the offshore oil and gas platforms, offshore wind turbines, and cryogenic transportation by sea. L'Air Liquide S.A. was incorporated in 1902 and is headquartered in Paris, France.",
#  'city': 'Paris',
#  'phone': '33 1 40 62 55 55',
#  'country': 'France',
#  'companyOfficers': [],
#  'website': 'https://www.airliquide.com',
#  'maxAge': 1,
#  'address1': "75 quai d'Orsay",
#  'industry': 'Specialty Chemicals',
#  'address2': 'cedex 07',
#  'ebitdaMargins': 0.2347,
#  'profitMargins': 0.098809995,
#  'grossMargins': 0.55701,
#  'operatingCashflow': 5621199872,
#  'revenueGrowth': 0.31,
#  'operatingMargins': 0.15854,
#  'ebitda': 6265500160,
#  'targetLowPrice': 117,
#  'recommendationKey': 'buy',
#  'grossProfits': 13946100000,
#  'freeCashflow': 1803737472,
#  'targetMedianPrice': 155.5,
#  'currentPrice': 132.82,
#  'earningsGrowth': 0.043,
#  'currentRatio': 0.832,
#  'returnOnAssets': 0.056500003,
#  'numberOfAnalystOpinions': 26,
#  'targetMeanPrice': 154.16,
#  'debtToEquity': 62.158,
#  'returnOnEquity': 0.12774,
#  'targetHighPrice': 177.27,
#  'totalCash': 1519699968,
#  'totalDebt': 14851900416,
#  'totalRevenue': 26695700480,
#  'totalCashPerShare': 2.913,
#  'financialCurrency': 'EUR',
#  'revenuePerShare': 51.31,
#  'quickRatio': 0.519,
#  'recommendationMean': 2.1,
#  'exchange': 'PAR',
#  'shortName': 'AIR LIQUIDE',
#  'longName': "L'Air Liquide S.A.",
#  'exchangeTimezoneName': 'Europe/Paris',
#  'exchangeTimezoneShortName': 'CEST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '7200000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AI.PA',
#  'messageBoardId': 'finmb_873964',
#  'market': 'fr_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 3.122,
#  'beta3Year': None,
#  'enterpriseToEbitda': 13.303,
#  '52WeekChange': 0.008510947,
#  'morningStarRiskRating': None,
#  'forwardEps': 6.33,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 522148992,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 44.087,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.30919,
#  'netIncomeToCommon': 2637700096,
#  'trailingEps': 5.05,
#  'lastDividendValue': 2.636364,
#  'SandP52WeekChange': -0.15215701,
#  'priceToBook': 3.0126796,
#  'heldPercentInsiders': 0.02803,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1656547200,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': 510990789,
#  'beta': 0.621737,
#  'enterpriseValue': 83352436736,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1654473600,
#  'lastSplitFactor': '11:10',
#  'legalType': None,
#  'lastDividendDate': 1652659200,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.053,
#  'priceToSalesTrailing12Months': 2.5978653,
#  'dateShortInterest': None,
#  'pegRatio': 1.81,
#  'ytdReturn': None,
#  'forwardPE': 20.982624,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 132.5,
#  'regularMarketOpen': 132.8,
#  'twoHundredDayAverage': 134.3804,
#  'trailingAnnualDividendYield': 0.01989434,
#  'payoutRatio': 0.5223,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 134.22,
#  'navPrice': None,
#  'averageDailyVolume10Day': 791182,
#  'regularMarketPreviousClose': 132.5,
#  'fiftyDayAverage': 123.1772,
#  'trailingAnnualDividendRate': 2.636,
#  'open': 132.8,
#  'toCurrency': None,
#  'averageVolume10days': 791182,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 2.64,
#  'exDividendDate': 1652659200,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 131.28,
#  'currency': 'EUR',
#  'trailingPE': 26.300991,
#  'regularMarketVolume': 879054,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 69351833600,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 717581,
#  'dayLow': 131.28,
#  'ask': 0,
#  'askSize': 0,
#  'volume': 879054,
#  'fiftyTwoWeekHigh': 153.4,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 2.1,
#  'fiftyTwoWeekLow': 114.44,
#  'bid': 0,
#  'tradeable': False,
#  'dividendYield': 0.0199,
#  'bidSize': 0,
#  'dayHigh': 134.22,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 132.82,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/airliquide.com'}

# %%
list_shortName = []
list_sector = []
list_priceToBook = []
list_dividendYield = []
list_pegRatio = []
list_beta = []
list_ebitdaMargins = []

# %%
d = {
        "symbol": list_cac40,
        "shortName": list_shortName,
        "sector": list_sector,
        "priceToBook": list_priceToBook,
        "dividendYield": list_dividendYield,
        "pegRatio": list_pegRatio,
        "beta": list_beta,
        "ebitdaMargins": list_ebitdaMargins
}

# %%
for company in list_cac40:
    data = yf.Ticker(company)
    list_shortName.append(data.info.get('shortName'))
    list_sector.append(data.info.get('sector'))
    list_priceToBook.append(data.info.get('priceToBook'))
    list_dividendYield.append(data.info.get('dividendYield'))
    list_pegRatio.append(data.info.get('pegRatio'))
    list_beta.append(data.info.get('beta'))
    list_ebitdaMargins.append(data.info.get('ebitdaMargins'))

# %%
df = pd.DataFrame(d)

# %%
df.head()
# Out:
#    symbol         shortName              sector  priceToBook  dividendYield  \
# 0   AI.PA       AIR LIQUIDE     Basic Materials     3.012680         0.0199
# 1  AIR.PA         AIRBUS SE         Industrials     9.608929         0.0144
# 2  ALO.PA            ALSTOM         Industrials     0.848523         0.0131
# 3   MT.AS  ARCELORMITTAL SA     Basic Materials     0.366456         0.0157
# 4   CS.PA               AXA  Financial Services     1.086652         0.0617
#
#    pegRatio      beta  ebitdaMargins
# 0      1.81  0.621737        0.23470
# 1      0.94  1.814291        0.12476
# 2      1.11  0.860077        0.04996
# 3     -0.07  2.056482        0.24701
# 4      0.99  1.425759        0.10252

# %%
df.describe()
# Out:
#        priceToBook  dividendYield   pegRatio       beta  ebitdaMargins
# count    40.000000      37.000000  19.000000  38.000000      40.000000
# mean      2.843258       0.033705   1.221579   1.081302       0.186682
# std       2.988877       0.026348   1.136800   0.488477       0.110829
# min       0.320093       0.004600  -1.580000   0.151892       0.000000
# 25%       0.720006       0.015300   0.630000   0.732966       0.118115
# 50%       1.716972       0.021600   0.990000   0.983229       0.181105
# 75%       3.728442       0.046200   1.935000   1.380450       0.237550
# max      13.929365       0.116400   2.990000   2.161396       0.532890

# %%
plt.subplots(figsize=(10, 10))

plt.barh(df["shortName"], df["priceToBook"])

plt.show()
